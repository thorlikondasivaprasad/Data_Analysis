# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('Z:\y21cs174\Data Analysis Lab\pizza_price_prediction_5thquestion.csv')
data
# Out:
#     company price_cad  diameter      topping           variant     size  \
# 0         A      $29    22 inch      chicken  double_signature    jumbo
# 1         A      $25    20 inch    papperoni  double_signature    jumbo
# 2         A      $19    16 inch    mushrooms  double_signature  reguler
# 3         A      $22    14 inch  smoked_beef  double_signature  reguler
# 4         A      $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...       ...       ...          ...               ...      ...
# 124       E      $11   8.5 inch         tuna        spicy tuna    small
# 125       E      $14    12 inch         tuna        spicy tuna   medium
# 126       E      $17    14 inch         tuna        spicy tuna    large
# 127       E      $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E      $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms
# 0           yes          yes              no
# 1           yes          yes              no
# 2           yes          yes             yes
# 3           yes           no             yes
# 4           yes           no             yes
# ..          ...          ...             ...
# 124         yes          yes             yes
# 125         yes          yes             yes
# 126         yes          yes             yes
# 127         yes           no             yes
# 128          no           no             yes
#
# [129 rows x 9 columns]

# %%
count_null = data.isnull().sum().sum()
count_null
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company          129 non-null    object
#  1   price_cad        129 non-null    object
#  2   diameter         129 non-null    object
#  3   topping          129 non-null    object
#  4   variant          129 non-null    object
#  5   size             129 non-null    object
#  6   extra_sauce      129 non-null    object
#  7   extra_cheese     129 non-null    object
#  8   extra_mushrooms  129 non-null    object
# dtypes: object(9)
# memory usage: 9.2+ KB

# %% [markdown]
# # b)	Calculate average price of pizza prepared by each company.

# %%
data['price'] = [int(i[1:]) for i in data['price_cad']] # for removing $ symbol from price
data.groupby('company')['price'].mean()
# Out:
# company
# A    19.600
# B    14.375
# C    13.800
# D    16.600
# E    14.400
# Name: price, dtype: float64

# %% [markdown]
# # c)	Find the companies, who prepared pizzas with different variants with same diameter.

# %%
data.groupby(['company','diameter']).filter(lambda x : x['variant'].nunique()>1)
# group by each company and diameter ,filtering the
# Out:
#     company price_cad   diameter       topping            variant     size  \
# 0         A      $29     22 inch       chicken   double_signature    jumbo
# 2         A      $19     16 inch     mushrooms   double_signature  reguler
# 3         A      $22     14 inch   smoked_beef   double_signature  reguler
# 5         A      $20   18.5 inch  black_papper  american_favorite    jumbo
# 6         A      $18     16 inch   smoked_beef  american_favorite    jumbo
# ..      ...       ...        ...           ...                ...      ...
# 124       E      $11    8.5 inch          tuna         spicy tuna    small
# 125       E      $14     12 inch          tuna         spicy tuna   medium
# 126       E      $17     14 inch          tuna         spicy tuna    large
# 127       E      $12    8.5 inch          meat    BBQ_meat_fiesta    small
# 128       E      $15     12 inch          meat    BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms  price
# 0           yes          yes              no     29
# 2           yes          yes             yes     19
# 3           yes           no             yes     22
# 5            no           no             yes     20
# 6            no          yes             yes     18
# ..          ...          ...             ...    ...
# 124         yes          yes             yes     11
# 125         yes          yes             yes     14
# 126         yes          yes             yes     17
# 127         yes           no             yes     12
# 128          no           no             yes     15
#
# [99 rows x 10 columns]

# %% [markdown]
# # d)	Which company has more pizzas? Show the result with graph.

# %%
import matplotlib.pyplot as plt
d1=data.groupby('company')['variant'].count()
maxi= d1.max()
graph=['red' if i==maxi else 'blue' for i in d1]
plt.bar(d1.index,d1,color=graph)
plt.title("company vs no.of pizzas")
# Out:
# Text(0.5, 1.0, 'company vs no.of pizzas')

# %% [markdown]
# # e)	Check whether the pizza data set contains null value or not. /Count the no. of null values in the pizza dataset./ Find the number of missing data points per column.

# %%
data.isnull().sum()
# Out:
# company            0
# price_cad          0
# diameter           0
# topping            0
# variant            0
# size               0
# extra_sauce        0
# extra_cheese       0
# extra_mushrooms    0
# price              0
# dtype: int64

# %% [markdown]
# # f)Rename the column price_cad as price.

# %%
print(data)
data.rename(columns={'price':'price_cad','price_cad':'price'},inplace=True)
print(data)
# Out:
#     company price_cad  diameter      topping           variant     size  \
# 0         A      $29    22 inch      chicken  double_signature    jumbo
# 1         A      $25    20 inch    papperoni  double_signature    jumbo
# 2         A      $19    16 inch    mushrooms  double_signature  reguler
# 3         A      $22    14 inch  smoked_beef  double_signature  reguler
# 4         A      $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...       ...       ...          ...               ...      ...
# 124       E      $11   8.5 inch         tuna        spicy tuna    small
# 125       E      $14    12 inch         tuna        spicy tuna   medium
# 126       E      $17    14 inch         tuna        spicy tuna    large
# 127       E      $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E      $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms  price  diamet
# 0           yes          yes              no     29    22.0
# 1           yes          yes              no     25    20.0
# 2           yes          yes             yes     19    16.0
# 3           yes           no             yes     22    14.0
# 4           yes           no             yes     30    18.0
# ..          ...          ...             ...    ...     ...
# 124         yes          yes             yes     11     8.5
# 125         yes          yes             yes     14    12.0
# 126         yes          yes             yes     17    14.0
# 127         yes           no             yes     12     8.5
# 128          no           no             yes     15    12.0
#
# [129 rows x 11 columns]
#     company price  diameter      topping           variant     size  \
# 0         A  $29    22 inch      chicken  double_signature    jumbo
# 1         A  $25    20 inch    papperoni  double_signature    jumbo
# 2         A  $19    16 inch    mushrooms  double_signature  reguler
# 3         A  $22    14 inch  smoked_beef  double_signature  reguler
# 4         A  $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...   ...       ...          ...               ...      ...
# 124       E  $11   8.5 inch         tuna        spicy tuna    small
# 125       E  $14    12 inch         tuna        spicy tuna   medium
# 126       E  $17    14 inch         tuna        spicy tuna    large
# 127       E  $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E  $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms  price_cad  diamet
# 0           yes          yes              no         29    22.0
# 1           yes          yes              no         25    20.0
# 2           yes          yes             yes         19    16.0
# 3           yes           no             yes         22    14.0
# 4           yes           no             yes         30    18.0
# ..          ...          ...             ...        ...     ...
# 124         yes          yes             yes         11     8.5
# 125         yes          yes             yes         14    12.0
# 126         yes          yes             yes         17    14.0
# 127         yes           no             yes         12     8.5
# 128          no           no             yes         15    12.0
#
# [129 rows x 11 columns]

# %%
data.head(15)
# Out:
#    company price   diameter       topping            variant     size  \
# 0        A  $29     22 inch       chicken   double_signature    jumbo
# 1        A  $25     20 inch     papperoni   double_signature    jumbo
# 2        A  $19     16 inch     mushrooms   double_signature  reguler
# 3        A  $22     14 inch   smoked_beef   double_signature  reguler
# 4        A  $30     18 inch    mozzarella   double_signature    jumbo
# 5        A  $20   18.5 inch  black_papper  american_favorite    jumbo
# 6        A  $18     16 inch   smoked_beef  american_favorite    jumbo
# 7        A  $14      8 inch     papperoni  american_favorite  reguler
# 8        A  $16     12 inch     mushrooms  american_favorite  reguler
# 9        A  $16     12 inch   smoked_beef  american_favorite  reguler
# 10       A  $20   18.5 inch    mozzarella      super_supreme    jumbo
# 11       A  $18     16 inch  black_papper      super_supreme    jumbo
# 12       A  $14      8 inch   smoked_beef      super_supreme  reguler
# 13       A  $16     12 inch  black_papper      super_supreme  reguler
# 14       A  $16     12 inch    mozzarella      super_supreme  reguler
#
#    extra_sauce extra_cheese extra_mushrooms  price_cad  diamet
# 0          yes          yes              no         29    22.0
# 1          yes          yes              no         25    20.0
# 2          yes          yes             yes         19    16.0
# 3          yes           no             yes         22    14.0
# 4          yes           no             yes         30    18.0
# 5           no           no             yes         20    18.5
# 6           no          yes             yes         18    16.0
# 7           no           no             yes         14     8.0
# 8          yes           no             yes         16    12.0
# 9           no           no              no         16    12.0
# 10          no           no              no         20    18.5
# 11         yes          yes              no         18    16.0
# 12         yes          yes              no         14     8.0
# 13          no          yes              no         16    12.0
# 14          no          yes              no         16    12.0

# %% [markdown]
# # g)	Identify the number of companies in each category

# %%
data.groupby('variant')['company'].unique()
# Out:
# variant
# BBQ_meat_fiesta         [C, E]
# BBQ_sausage                [C]
# american_classic           [C]
# american_favorite          [A]
# classic              [B, D, E]
# crunchy              [B, D, E]
# double_decker        [B, D, E]
# double_mix              [A, D]
# double_signature           [A]
# extravaganza               [C]
# gournet_greek              [C]
# italian_veggie             [C]
# meat_eater                 [C]
# meat_lovers             [A, D]
# neptune_tuna               [C]
# new_york             [B, D, E]
# spicy tuna                 [E]
# spicy_tuna                 [C]
# super_supreme              [A]
# thai_veggie                [C]
# Name: company, dtype: object

# %% [markdown]
# # h)	Identify which type of pizza is more expensive.

# %%
data[data['price']==max(data['price'])]
# Out:
#   company price_cad diameter     topping           variant   size extra_sauce  \
# 4       A      $30   18 inch  mozzarella  double_signature  jumbo         yes
#
#   extra_cheese extra_mushrooms  price
# 4           no             yes     30

# %% [markdown]
# # i)	Find diameter of each jumbo size pizza.

# %%
data[data['size']=='jumbo']['diameter']
# Out:
# 0       22 inch
# 1       20 inch
# 4       18 inch
# 5     18.5 inch
# 6       16 inch
# 10    18.5 inch
# 11      16 inch
# 15    18.5 inch
# 16      16 inch
# 20      22 inch
# 21    18.5 inch
# 79    18.5 inch
# 80      16 inch
# 84      22 inch
# 85    18.5 inch
# Name: diameter, dtype: object

# %% [markdown]
# # j)	Any jumbo pizza with diameter less than 16 exists, remove such rows.

# %%
data['diamet']= [float(i[:-5]) for i in data['diameter']]   # for removing ' inch' from the end of the diameter column
filter_data=data[data['diamet']<16.0].index                 # index of such rows <16.0
data.drop(filter_data)
# Out:
#     company price_cad   diameter       topping            variant     size  \
# 0         A      $29     22 inch       chicken   double_signature    jumbo
# 1         A      $25     20 inch     papperoni   double_signature    jumbo
# 2         A      $19     16 inch     mushrooms   double_signature  reguler
# 4         A      $30     18 inch    mozzarella   double_signature    jumbo
# 5         A      $20   18.5 inch  black_papper  american_favorite    jumbo
# 6         A      $18     16 inch   smoked_beef  american_favorite    jumbo
# 10        A      $20   18.5 inch    mozzarella      super_supreme    jumbo
# 11        A      $18     16 inch  black_papper      super_supreme    jumbo
# 15        A      $20   18.5 inch    mozzarella        meat_lovers    jumbo
# 16        A      $18     16 inch   smoked_beef        meat_lovers    jumbo
# 20        A      $28     22 inch       chicken         double_mix    jumbo
# 21        A      $25   18.5 inch     mushrooms         double_mix    jumbo
# 23        A      $21   16.5 inch   smoked_beef         double_mix  reguler
# 24        A      $21   16.5 inch       chicken         double_mix  reguler
# 29        B      $15     17 inch       chicken           new_york       XL
# 35        B      $18     17 inch    mozzarella           new_york       XL
# 41        B      $18     17 inch     mushrooms           new_york       XL
# 47        B      $15     17 inch       chicken           new_york       XL
# 79        D      $20   18.5 inch    mozzarella        meat_lovers    jumbo
# 80        D      $18     16 inch   smoked_beef        meat_lovers    jumbo
# 84        D      $28     22 inch       chicken         double_mix    jumbo
# 85        D      $25   18.5 inch     mushrooms         double_mix    jumbo
# 87        D      $21   16.5 inch   smoked_beef         double_mix  reguler
# 88        D      $21   16.5 inch       chicken         double_mix  reguler
# 93        D      $15     17 inch       chicken           new_york       XL
# 99        E      $18     17 inch    mozzarella           new_york       XL
# 104       E      $15     17 inch       chicken           new_york       XL
# 110       E      $18     17 inch    mozzarella           new_york       XL
# 116       E      $18     17 inch     mushrooms           new_york       XL
# 122       E      $15     17 inch       chicken           new_york       XL
#
#     extra_sauce extra_cheese extra_mushrooms  price  diamet
# 0           yes          yes              no     29    22.0
# 1           yes          yes              no     25    20.0
# 2           yes          yes             yes     19    16.0
# 4           yes           no             yes     30    18.0
# 5            no           no             yes     20    18.5
# 6            no          yes             yes     18    16.0
# 10           no           no              no     20    18.5
# 11          yes          yes              no     18    16.0
# 15           no          yes             yes     20    18.5
# 16           no          yes             yes     18    16.0
# 20          yes          yes             yes     28    22.0
# 21          yes          yes             yes     25    18.5
# 23          yes           no              no     21    16.5
# 24          yes           no              no     21    16.5
# 29           no          yes             yes     15    17.0
# 35           no          yes             yes     18    17.0
# 41          yes           no              no     18    17.0
# 47           no          yes              no     15    17.0
# 79           no          yes              no     20    18.5
# 80           no          yes              no     18    16.0
# 84          yes          yes             yes     28    22.0
# 85          yes          yes             yes     25    18.5
# 87          yes           no             yes     21    16.5
# 88          yes           no             yes     21    16.5
# 93           no          yes             yes     15    17.0
# 99           no          yes             yes     18    17.0
# 104          no          yes              no     15    17.0
# 110          no          yes             yes     18    17.0
# 116         yes           no              no     18    17.0
# 122          no          yes              no     15    17.0

# %% [markdown]
# # k)	Calculate average price of a pizza prepared by company A.

# %%
data[data['company']== 'A']['price'].mean()
# Out:
# 19.6

# %% [markdown]
# # l)	Find the mean of the diameter and average price of pizzas prepared by company C.

# %%
print(data[data['company']=='C']['diamet'].mean())
# Out:
# 11.5

# %%
print(data[data['company']=='C']['price'].mean())
# Out:
# 13.8

# %% [markdown]
# # m)	Find the companies, who prepared pizzas with different variants with same diameter.

# %%
data.groupby(['company','diamet']).filter(lambda x: x['variant'].nunique()>1)['company']
# Out:
# 0      A
# 2      A
# 3      A
# 5      A
# 6      A
#       ..
# 124    E
# 125    E
# 126    E
# 127    E
# 128    E
# Name: company, Length: 100, dtype: object

# %% [markdown]
# # n)	Find the pizza variant with extra_mushrooms and topping with chicken.

# %%
d3=data[data['topping']=='chicken']
d3[d3['extra_mushrooms']=='yes']['variant']
# Out:
# 17       meat_lovers
# 20        double_mix
# 22        double_mix
# 29          new_york
# 30     double_decker
# 32           classic
# 37           classic
# 84        double_mix
# 86        double_mix
# 88        double_mix
# 90           classic
# 93          new_york
# 101          classic
# 107          classic
# 112          classic
# 114          classic
# 115          crunchy
# Name: variant, dtype: object

# %% [markdown]
# # o)	What is the most expensive pizza in each company?

# %%
data.groupby(['company'])['price'].max()
# Out:
# company
# A    $30
# B    $19
# C    $17
# D    $28
# E    $19
# Name: price, dtype: object

# %% [markdown]
# # p)	Which company has more pizzas on the menu? Show the result with graph.

# %%
d1=data.groupby('company')['variant'].count()
val=d1.max()
col= ['red' if i==val else 'blue' for i in d1]
plt.bar(d1.index,d1,color=col)
plt.title('Company vs No.of.Pizzas')
# Out:
# Text(0.5, 1.0, 'Company vs No.of.Pizzas')

# %% [markdown]
# # q)	What is the average price of pizza in each company?

# %%
import pandas as pd
a=data.groupby(['company'])['price_cad'].mean()
b=data.groupby(['company'])['diamet'].mean()

print(a)
# Out:
# company
# A    19.600
# B    14.375
# C    13.800
# D    16.600
# E    14.400
# Name: price_cad, dtype: float64
