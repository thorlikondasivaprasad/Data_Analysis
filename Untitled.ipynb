# %%
# importing dependencies/modules

# %%
import numpy as np

import pandas as pd

# %% [markdown]
# # 1.Loading the dataset

# %%
data= pd.read_csv('Z:\y21cs174\DA Lab\DataFrames_Dataset_4thQuestion.csv')
data
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      4/9/2012       58                 8                4
# ...

# %% [markdown]
# # 2.a print first 5 rows,last 5 rows of data

# %%
print(data.head())   # head()
print(data.tail())   # tail()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      4/9/2012       58                 8                4
# 1        46344.0      8/3/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     10/2/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %% [markdown]
# #  2.2 Check the basic Information of data

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        499 non-null    int64
#  1   year_of_birth      499 non-null    int64
#  2   educational_level  499 non-null    object
#  3   marital_status     499 non-null    object
#  4   annual_income      486 non-null    float64
#  5   purhcase_date      499 non-null    object
#  6   recency            499 non-null    int64
#  7   online_purchases   499 non-null    int64
#  8   store_purchases    499 non-null    int64
#  9   complaints         499 non-null    int64
#  10  calls              499 non-null    int64
#  11  intercoms          499 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 46.9+ KB
# None

# %% [markdown]
# # 2.3 Extract the shape of the data

# %%
print(data.shape)
# Out:
# (499, 12)

# %%
uniqu = data["marital_status"].unique()
print(uniqu)
# Out:
# ['Single' 'Married' 'Divorced' 'Relationship' 'Widowed' 'Widow']

# %%
replac = data["marital_status"].replace('Widowed','Widow')
print("Widowed is replaced with Widow \n",replac,"\n\n\n")
# Out:
# Widowed is replaced with Widow
#  0            Single
# 1           Married
# 2          Divorced
# 3      Relationship
# 4             Widow
#            ...
# 494        Divorced
# 495        Divorced
# 496        Divorced
# 497    Relationship
# 498    Relationship
# Name: marital_status, Length: 499, dtype: object

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
print(data.isnull().sum())
# Out:
# customer_id           0
# year_of_birth         0
# educational_level     0
# marital_status        0
# annual_income        13
# purhcase_date         0
# recency               0
# online_purchases      0
# store_purchases       0
# complaints            0
# calls                 0
# intercoms             0
# dtype: int64

# %% [markdown]
# #  3. select and filter data based on conditions
# # 3.1 a.	Select a subset of the data points(Birthdate, Education, and Income of every customer) from the data frame

# %%
df=data
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      4/9/2012       58                 8                4
# ...

# %%
subset= data[['year_of_birth ','educational_level','annual_income']]
print(subset)
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 494            1944               PhD        55614.0
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
#
# [499 rows x 3 columns]

# %%
loc = data.loc[0:7,:]
print("loc() used for label indexing, \n",loc)
iloc = data.iloc[0:7,:]
print("iloc() used for position-based indexing, \n",iloc)
# Out:
# loc() used for label indexing,
#     customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
# 7     20201708            1985               PhD        Married
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      4/9/2012       58                 8                4
# 1        46344.0      8/3/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# ...

# %% [markdown]
# # 3.c  Filter data using the loc() and isin() methods.(Note:we choose the educational level , we select the categories as Graduation,PhD )

# %%
filtered_data = data.loc[df['educational_level'].isin(['Graduation','PhD'])]
print(filtered_data)
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 492     20202193            1955        Graduation   Relationship
# 494     20202195            1944               PhD       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      4/9/2012       58                 8                4
# ...

# %% [markdown]
# # 3d.	In our data, that satisfies two conditions such as choosing the customers with an income higher than 75,000 and with a master’s degree(using python operators) and display the output.

# %%
filtered_data_combine = data.loc[(df['educational_level']=='Master') & (df['annual_income']>75000)]
print(filtered_data_combine)
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %% [markdown]
# # 3  IV.	apply various data operation tools such as creating new variables or changing data types

# %% [markdown]
# # 3a.	setting a new index with the variable of our interest using the .set_index() method

# %%
set_index = data.set_index('customer_id')
print(set_index)
# Out:
#              year_of_birth  educational_level marital_status  annual_income  \
# customer_id
# 20201701               1982        Graduation         Single        58138.0
# 20201702               1950        Graduation        Married        46344.0
# 20201703               1965        Graduation       Divorced        71613.0
# 20201704               1984        Graduation   Relationship        26646.0
# 20201705               1981               PhD        Widowed        58293.0
# ...                     ...               ...            ...            ...
# 20202195               1944               PhD       Divorced        55614.0
# 20202196               1962            Master       Divorced        59432.0
# 20202197               1978        Graduation       Divorced        55563.0
# 20202198               1971               PhD   Relationship        43624.0
# 20202199               1949               PhD   Relationship        41461.0
#
# ...

# %%
# Sort the DataFrame by the 'Income' column in ascending order
# df = df.sort_values(by='Income', ascending=True)

sort = data.sort_values(by='annual_income', ascending=True)
print(sort)
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 21      20201722            1979        Graduation   Relationship
# 66      20201767            1983        Graduation   Relationship
# 9       20201710            1950               PhD         Single
# 238     20201939            1983        Graduation        Widowed
# 44      20201745            1975            Master   Relationship
# ..           ...             ...               ...            ...
# 92      20201793            1973            Master   Relationship
# 128     20201829            1961               PhD        Married
# 133     20201834            1980        Graduation   Relationship
# 312     20202013            1990        Graduation         Single
# 319     20202020            1997        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 21          2447.0      6/1/2013       42                 0                0
# ...

# %%
new_var = data['online_purchases'] + data['store_purchases']
print(new_var)
# Out:
# 0      12
# 1       3
# 2      18
# 3       6
# 4      11
#        ..
# 494    15
# 495    16
# 496     5
# 497     8
# 498    17
# Length: 499, dtype: int64
